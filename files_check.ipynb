# %%
# !find . -type f -size +100M
# Out:
# ./Screen Recording 2019-12-06 at 8.10.02 PM.mov
# ./Assignment6Hbase/hbase-1.4.10/hbase-1.4.10.noupload.zip
# ./Assignment6Hbase/hbase-1.4.10/hbase-1.4.10-bin.noupload.tar.gz
# ./Assignment11ElasticSearch/kibana-7.4.2-darwin-x86_64/kibana-7.4.2-darwin-x86_64.noupload.zip
# ./Assignment11ElasticSearch/elasticsearch-7.4.2/elasticsearch-7.4.2.noupload.zip
# ./Assignment11ElasticSearch/elasticsearch-7.4.2/elasticsearch-7.4.2-darwin-x86_64.noupload.tar.gz
# ./Assignment10Cassandra/apache-cassandra-3.11.5/apache-cassandra-3.11.5-bin.noupload.tar

# %%
# !find . -type f -size +50M
# Out:
# ./Assignment9SparkStreaming/kafka_2.11-2.2.1/kafka_2.11-2.2.1.noupload.zip
# ./Cheng_Loi_Final_Project.zip
# ./Screen Recording 2019-12-06 at 8.10.02 PM.mov
# ./Assignment6Hbase/hbase-1.4.10/hbase-1.4.10.noupload.zip
# ./Assignment6Hbase/hbase-1.4.10/hbase-1.4.10-bin.noupload.tar.gz
# ./Assignment11ElasticSearch/kibana-7.4.2-darwin-x86_64/kibana-7.4.2-darwin-x86_64.noupload.zip
# ./Assignment11ElasticSearch/elasticsearch-7.4.2/elasticsearch-7.4.2.noupload.zip
# ./Assignment11ElasticSearch/elasticsearch-7.4.2/elasticsearch-7.4.2-darwin-x86_64.noupload.tar.gz
# ./Final_Project/Project/docker_share/apache-flume-1.9.0-bin/apache-flume-1.9.0-bin.noupload.tar.gz
# ./Assignment10Cassandra/apache-cassandra-3.11.5/apache-cassandra-3.11.5.noupload.zip
# ./Assignment10Cassandra/apache-cassandra-3.11.5/apache-cassandra-3.11.5-bin.noupload.tar

# %%
#!ls -lR --block-size=MB

# %%
# !ls -lhRS
# Out:
# total 553096
# -rw-r--r--@  1 loi  staff   174M Dec  6  2019 Screen Recording 2019-12-06 at 8.10.02 PM.mov
# -rw-------   1 loi  staff    78M Dec  6  2019 Cheng_Loi_Final_Project.zip
# -rw-r--r--@  1 loi  staff    12M Dec 14  2019 cscie88_Apache_Beam_Flink_Intro.zip
# -rw-------@  1 loi  staff   1.7M Dec 18  2019 Week 16_ Principles of Big Data Processing.mhtml
# -rw-r--r--   1 loi  staff   110K Aug  3 17:19 files_check.ipynb
# -rw-r--r--   1 loi  staff   2.8K Jul 28 21:27 git_push.ipynb
# drwx------@ 43 loi  staff   1.3K Dec 18  2019 DCE Paella Engage Video Player_files .noupload
# drwxr-xr-x  41 loi  staff   1.3K Aug  3 16:10 Assignment5Spark
# drwxr-xr-x  38 loi  staff   1.2K Oct 12  2019 Assignment4Hadoop
# drwxr-xr-x  36 loi  staff   1.1K Aug  3 17:09 Assignment6Hbase
# drwxr-xr-x  32 loi  staff   1.0K Oct 12  2019 Assignment2AWS
# drwxr-xr-x  28 loi  staff   896B Aug  3 16:10 Assignment3Redis
# drwxr-xr-x  25 loi  staff   800B Aug  3 17:12 Assignment10Cassandra
# ...

# %%
# !find ./ -type f | wc -l
# Out:
#     3483
