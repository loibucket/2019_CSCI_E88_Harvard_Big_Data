# %%
import pandas as pd
import numpy as np
import random

# %%
def generate_df(id_list, timestring, min_interval, max_interval, url_list, user_list, country_list):

    df = pd.DataFrame(id_list)
    df[0] = df[0].astype(str).apply(lambda x: 'id'+x)

    #generate incremental time
    #time_list = [pd.Timestamp('2019-11-22T00Z')]
    time_list = [pd.Timestamp(timestring)]
    for i in range(1,len(df)):
        time_list.append( time_list[-1] + pd.Timedelta(seconds=random.randint(min_interval,max_interval)) )
    df[1] = time_list

    #generate url
    df[2] = np.random.choice(url_list, size=len(df))

    #generate user
    df[3] = np.random.choice(user_list, size=len(df))

    #generate country
    df[4] = np.random.choice(country_list, size=len(df))

    #generate browser
    df[5]  = np.random.choice(['Chrome','Firefox','Edge','IE'], size=len(df))

    #generate OS
    df[6] = np.random.choice(['Mac','Linux','iPhone','Windows'], size=len(df))

    #generate Response
    df[7] = np.random.randint(100,600,size=len(df))

    #generate TTFB
    df[8] = np.random.uniform(0.1,13,size=len(df))
    df[8] = df[8].round(3)
    
    return df

# %%
url_list = ['http://100.com/100','http://200.com/200','http://300.com/300',\
                'http://400.com/400','http://500.com/500']

user_list = ['user9000','user800','user10','user77','user55']

country_list = ['ER','SJ','MA','GD','ZW']

big_url_list = url_list + ['http://google.com/cow','http://bing.com/cat','http://espn.com/ball',\
                'http://espn.com/ball','http://amazon.com/fire']

big_user_list = user_list + ['bob','carly','moo','bigbig','buck']

big_country_list = country_list + ['AF','AL','AS','AD','AQ']

timestring = '2019-11-22T12Z'
id_list = list(range(0,21))
min_interval = 100
max_interval = 200

df_1 = generate_df(id_list, timestring, min_interval, max_interval, url_list, user_list, country_list)

timestring = '2019-11-22T13Z'
id_list = list(range(21,51))
min_interval = 100
max_interval = 200

df_2 = generate_df(id_list, timestring, min_interval, max_interval, big_url_list, big_user_list, big_country_list)

timestring = '2019-11-22T14Z'
id_list = list(range(51,60))
min_interval = 100
max_interval = 200

df_3 = generate_df(id_list, timestring, min_interval, max_interval, url_list, user_list, country_list)


df = pd.concat([df_1,df_2,df_3])
df = df.reset_index(drop = True)
df = df.rename(columns={0: "logId", 1: "eventTime", 2: "url", 3:"userId", 4:"us_country", 5:"browser", 6:"ua_os", 7:"responseCode", 8:"ttfb"})
df
# Out:
#    logId                 eventTime                     url    userId  \
# 0    id0 2019-11-22 12:00:00+00:00      http://400.com/400   user800
# 1    id1 2019-11-22 12:02:27+00:00      http://500.com/500    user55
# 2    id2 2019-11-22 12:05:10+00:00      http://100.com/100    user10
# 3    id3 2019-11-22 12:08:16+00:00      http://100.com/100   user800
# 4    id4 2019-11-22 12:10:46+00:00      http://300.com/300  user9000
# 5    id5 2019-11-22 12:13:09+00:00      http://100.com/100    user77
# 6    id6 2019-11-22 12:15:28+00:00      http://400.com/400   user800
# 7    id7 2019-11-22 12:17:46+00:00      http://500.com/500  user9000
# 8    id8 2019-11-22 12:19:35+00:00      http://300.com/300  user9000
# 9    id9 2019-11-22 12:22:01+00:00      http://300.com/300    user77
# 10  id10 2019-11-22 12:24:09+00:00      http://500.com/500    user55
# 11  id11 2019-11-22 12:25:50+00:00      http://300.com/300    user55
# 12  id12 2019-11-22 12:28:33+00:00      http://100.com/100  user9000
# 13  id13 2019-11-22 12:31:11+00:00      http://400.com/400    user55
# 14  id14 2019-11-22 12:33:38+00:00      http://400.com/400   user800
# 15  id15 2019-11-22 12:36:47+00:00      http://100.com/100    user10
# 16  id16 2019-11-22 12:39:44+00:00      http://300.com/300    user55
# 17  id17 2019-11-22 12:42:30+00:00      http://300.com/300    user10
# 18  id18 2019-11-22 12:44:44+00:00      http://200.com/200    user55
# 19  id19 2019-11-22 12:46:43+00:00      http://300.com/300  user9000
# 20  id20 2019-11-22 12:48:55+00:00      http://100.com/100    user55
# 21  id21 2019-11-22 13:00:00+00:00      http://300.com/300  user9000
# 22  id22 2019-11-22 13:02:14+00:00      http://500.com/500    user55
# 23  id23 2019-11-22 13:05:22+00:00     http://bing.com/cat       moo
# 24  id24 2019-11-22 13:08:08+00:00      http://200.com/200  user9000
# 25  id25 2019-11-22 13:11:17+00:00      http://400.com/400      buck
# 26  id26 2019-11-22 13:14:31+00:00    http://espn.com/ball     carly
# 27  id27 2019-11-22 13:16:29+00:00    http://espn.com/ball   user800
# 28  id28 2019-11-22 13:18:39+00:00    http://espn.com/ball    user77
# 29  id29 2019-11-22 13:21:45+00:00      http://500.com/500    user77
# 30  id30 2019-11-22 13:23:44+00:00      http://400.com/400     carly
# 31  id31 2019-11-22 13:25:40+00:00  http://amazon.com/fire       moo
# 32  id32 2019-11-22 13:27:28+00:00     http://bing.com/cat    user77
# 33  id33 2019-11-22 13:29:52+00:00    http://espn.com/ball     carly
# 34  id34 2019-11-22 13:31:39+00:00      http://500.com/500       moo
# 35  id35 2019-11-22 13:33:19+00:00  http://amazon.com/fire    user55
# 36  id36 2019-11-22 13:36:00+00:00      http://100.com/100    bigbig
# 37  id37 2019-11-22 13:38:02+00:00     http://bing.com/cat  user9000
# 38  id38 2019-11-22 13:40:19+00:00  http://amazon.com/fire    user55
# 39  id39 2019-11-22 13:43:21+00:00  http://amazon.com/fire    user77
# 40  id40 2019-11-22 13:45:24+00:00      http://200.com/200     carly
# 41  id41 2019-11-22 13:48:37+00:00      http://100.com/100    user77
# 42  id42 2019-11-22 13:51:53+00:00    http://espn.com/ball    user77
# 43  id43 2019-11-22 13:53:48+00:00      http://200.com/200       moo
# 44  id44 2019-11-22 13:56:11+00:00    http://espn.com/ball    user10
# 45  id45 2019-11-22 13:58:48+00:00      http://300.com/300   user800
# 46  id46 2019-11-22 14:01:45+00:00      http://100.com/100      buck
# 47  id47 2019-11-22 14:04:24+00:00     http://bing.com/cat     carly
# 48  id48 2019-11-22 14:06:32+00:00      http://200.com/200     carly
# 49  id49 2019-11-22 14:09:34+00:00      http://500.com/500     carly
# 50  id50 2019-11-22 14:11:55+00:00    http://espn.com/ball       moo
# 51  id51 2019-11-22 14:00:00+00:00      http://400.com/400    user77
# 52  id52 2019-11-22 14:02:31+00:00      http://500.com/500    user77
# 53  id53 2019-11-22 14:04:46+00:00      http://200.com/200    user10
# 54  id54 2019-11-22 14:07:44+00:00      http://300.com/300  user9000
# 55  id55 2019-11-22 14:10:28+00:00      http://500.com/500    user77
# 56  id56 2019-11-22 14:13:07+00:00      http://500.com/500    user55
# 57  id57 2019-11-22 14:15:18+00:00      http://200.com/200    user10
# 58  id58 2019-11-22 14:17:22+00:00      http://400.com/400   user800
# 59  id59 2019-11-22 14:19:19+00:00      http://400.com/400    user55
#
#    us_country  browser    ua_os  responseCode    ttfb
# 0          GD   Chrome   iPhone           269   1.870
# 1          MA       IE      Mac           322   0.594
# 2          ER   Chrome   iPhone           368   2.679
# 3          ER       IE      Mac           195   4.343
# 4          ER     Edge    Linux           567   1.792
# 5          MA  Firefox  Windows           444  10.796
# 6          SJ     Edge    Linux           428   0.858
# 7          ZW     Edge   iPhone           269   0.491
# 8          SJ   Chrome    Linux           310   1.617
# 9          ZW  Firefox    Linux           378   2.283
# 10         ER  Firefox      Mac           457   9.716
# 11         ER     Edge   iPhone           146   9.743
# 12         GD       IE      Mac           518   5.602
# 13         MA     Edge   iPhone           418   0.902
# 14         GD   Chrome  Windows           138   4.911
# 15         ER  Firefox      Mac           599   3.364
# 16         MA     Edge      Mac           134   4.487
# 17         ZW  Firefox      Mac           447   7.321
# 18         MA   Chrome    Linux           201   1.148
# 19         GD       IE    Linux           224   6.589
# 20         ZW       IE    Linux           469  12.480
# 21         SJ  Firefox    Linux           243   1.862
# 22         AD   Chrome   iPhone           209  10.826
# 23         AQ   Chrome      Mac           478   8.825
# 24         AD   Chrome    Linux           501   7.079
# 25         AD     Edge   iPhone           487   9.611
# 26         AF   Chrome   iPhone           505   4.904
# 27         GD  Firefox      Mac           246   1.304
# 28         AF   Chrome   iPhone           436   9.045
# 29         AD       IE      Mac           597   2.818
# 30         ZW       IE      Mac           308  11.855
# 31         AQ  Firefox      Mac           542   3.500
# 32         MA       IE      Mac           275   0.781
# 33         GD  Firefox   iPhone           387   7.305
# 34         ER     Edge   iPhone           303  11.910
# 35         AQ     Edge      Mac           499   1.507
# 36         MA       IE    Linux           430   4.727
# 37         AQ     Edge  Windows           194   0.561
# 38         AQ       IE   iPhone           258   8.772
# 39         ER   Chrome   iPhone           248   1.478
# 40         AL  Firefox   iPhone           539   4.965
# 41         AL   Chrome   iPhone           197   5.005
# 42         GD   Chrome   iPhone           585  12.155
# 43         AD     Edge   iPhone           517  10.199
# 44         AS   Chrome    Linux           161  12.741
# 45         AL       IE    Linux           111   5.683
# 46         ZW       IE    Linux           290   4.981
# 47         AF       IE      Mac           338   1.578
# 48         ER   Chrome    Linux           259   2.857
# 49         AD     Edge      Mac           586   4.163
# 50         MA   Chrome  Windows           439   0.859
# 51         ZW   Chrome   iPhone           480   9.759
# 52         ZW     Edge      Mac           301  12.650
# 53         ER  Firefox  Windows           448   9.960
# 54         GD     Edge   iPhone           462   9.995
# 55         MA       IE      Mac           387   8.388
# 56         MA  Firefox  Windows           431   2.357
# 57         ER     Edge    Linux           511   7.336
# 58         SJ     Edge   iPhone           518  11.476
# 59         ZW   Chrome    Linux           560   0.462

# %%
f = open("curl_p2.sh", "w")
for i in range(len(df)):
    f.write("""curl -XPOST 'localhost:9200/hw11_p2_index/_doc/""" +str(i)+ """?pretty' -H 'Content-Type: application/json' -d '""")
    f.write(df.iloc[i].to_json(orient='index'))
    f.write("""'\n""")
f.close()

# %%
import requests

headers = {
    'Content-type': 'application/json',
}

data=\
"""
{
    "logId":"id0000",
    "eventTime":"2018-04-10T15:15:30Z",
    "url":"http://google.com/rum2",
    "us_country":"Russia",
    "userId":"u3",
    "browser":"CHROME2",
    "ua_os":"MacOSX10.1",
    "responseCode":200,
    "ttfb":6.9
}
"""

#requests.post('http://localhost:9200/hw11_p2_index/_doc/0', headers=headers, data=data)

requests.post('http://localhost:9200/hw11_p2_index/_doc/0', headers=headers, data=df.iloc[0].to_json(orient='index'))
# Out:
# <Response [200]>

# %%
from elasticsearch import Elasticsearch
es = Elasticsearch()

for i in range(len(df)):
    res = es.index(index="hw11_p2b5_index", doc_type='_doc', id=i, body=df.iloc[0].to_json(orient='index'))
    print(res['result'])
# Out:
# created
# created
# created
# created
# created
# created
# created
# created
# created
# created
# created
# created
# created
# created
# created
# created
# created
# created
# created
# created
# created
# created
# created
# created
# created
# created
# created
# created
# created
# created
# created
# created
# created
# created
# created
# created
# created
# created
# created
# created
# created
# created
# created
# created
# created
# created
# created
# created
# created
# created
# created
# created
# created
# created
# created
# created
# created
# created
# created
# created
