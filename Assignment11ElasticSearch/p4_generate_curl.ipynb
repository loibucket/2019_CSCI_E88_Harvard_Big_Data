# %%
import pandas as pd
import numpy as np
import random

# %%
def generate_df(id_list, timestring, min_interval, max_interval, url_list, user_list, country_list):

    df = pd.DataFrame(id_list)
    df[0] = df[0].astype(str).apply(lambda x: 'id'+x)

    #generate incremental time
    #time_list = [pd.Timestamp('2019-11-22T00Z')]
    time_list = [pd.Timestamp(timestring)]
    for i in range(1,len(df)):
        time_list.append( time_list[-1] + pd.Timedelta(seconds=random.randint(min_interval,max_interval)) )
    df[1] = time_list

    #generate url
    df[2] = np.random.choice(url_list, size=len(df))

    #generate user
    df[3] = np.random.choice(user_list, size=len(df))

    #generate country
    df[4] = np.random.choice(country_list, size=len(df))

    #generate browser
    df[5]  = np.random.choice(['Chrome','Firefox','Edge','IE'], size=len(df))

    #generate OS
    df[6] = np.random.choice(['Mac','Linux','iPhone','Windows'], size=len(df))

    #generate Response
    df[7] = np.random.randint(100,600,size=len(df))

    #generate TTFB
    df[8] = np.random.uniform(0.1,13,size=len(df))
    df[8] = df[8].round(3)
    
    return df

# %%
url_list = ['http://100.com/100','http://200.com/200','http://300.com/300',\
                'http://400.com/400','http://500.com/500']

user_list = ['user9000','user800','user10','user77','user55']

country_list = ['ER','SJ','MA','GD','ZW']

big_url_list = url_list + ['http://google.com/cow','http://bing.com/cat','http://espn.com/ball',\
                'http://espn.com/ball','http://amazon.com/fire']

big_user_list = user_list + ['bob','carly','moo','bigbig','buck']

big_country_list = country_list + ['AF','AL','AS','AD','AQ']

timestring = '2019-11-22T12Z'
id_list = list(range(0,21))
min_interval = 600
max_interval = 700

df_1 = generate_df(id_list, timestring, min_interval, max_interval, url_list, user_list, country_list)

timestring = '2019-11-22T16Z'
id_list = list(range(21,51))
min_interval = 600
max_interval = 800

df_2 = generate_df(id_list, timestring, min_interval, max_interval, big_url_list, big_user_list, big_country_list)

timestring = '2019-11-22T22Z'
id_list = list(range(51,60))
min_interval = 100
max_interval = 1000

df_3 = generate_df(id_list, timestring, min_interval, max_interval, url_list, user_list, country_list)


df = pd.concat([df_1,df_2,df_3])
df = df.reset_index(drop = True)
df = df.rename(columns={0: "logId", 1: "eventTime", 2: "url", 3:"userId", 4:"us_country", 5:"browser", 6:"ua_os", 7:"responseCode", 8:"ttfb"})

df
# Out:
#    logId                 eventTime                     url    userId  \
# 0    id0 2019-11-22 12:00:00+00:00      http://200.com/200    user10
# 1    id1 2019-11-22 12:10:01+00:00      http://200.com/200   user800
# 2    id2 2019-11-22 12:21:40+00:00      http://400.com/400    user55
# 3    id3 2019-11-22 12:31:51+00:00      http://100.com/100    user10
# 4    id4 2019-11-22 12:43:25+00:00      http://300.com/300    user10
# 5    id5 2019-11-22 12:54:15+00:00      http://100.com/100    user10
# 6    id6 2019-11-22 13:05:45+00:00      http://300.com/300   user800
# 7    id7 2019-11-22 13:17:01+00:00      http://200.com/200  user9000
# 8    id8 2019-11-22 13:28:06+00:00      http://400.com/400    user10
# 9    id9 2019-11-22 13:38:32+00:00      http://400.com/400    user55
# 10  id10 2019-11-22 13:49:14+00:00      http://200.com/200  user9000
# 11  id11 2019-11-22 13:59:45+00:00      http://200.com/200    user10
# 12  id12 2019-11-22 14:10:31+00:00      http://300.com/300  user9000
# 13  id13 2019-11-22 14:21:36+00:00      http://500.com/500    user10
# 59  id59 2019-11-22 23:17:19+00:00      http://200.com/200    user55
#
#    us_country  browser    ua_os  responseCode    ttfb
# 0          SJ   Chrome   iPhone           335   4.131
# 1          ER       IE      Mac           129  10.758
# 2          MA       IE    Linux           294   3.942
# 3          ZW       IE      Mac           470   3.310
# 4          SJ   Chrome    Linux           238   1.081
# 5          SJ   Chrome    Linux           177  10.264
# 6          MA       IE      Mac           270   5.340
# 7          ZW     Edge   iPhone           239   7.622
# 8          MA   Chrome      Mac           300  11.078
# 9          SJ  Firefox    Linux           488   5.917
# 10         SJ     Edge    Linux           324  12.609
# 11         ER  Firefox  Windows           123   7.834
# 12         ER  Firefox  Windows           384   1.444
# 13         SJ   Chrome   iPhone           337  11.084
# 14         ER       IE  Windows           200   1.163
# 15         MA       IE      Mac           541   2.061
# 16         MA       IE    Linux           486   3.740
# 17         SJ  Firefox      Mac           181   8.068
# 18         GD  Firefox    Linux           329   1.123
# 19         ZW     Edge  Windows           220  11.452
# 20         ER     Edge   iPhone           587  11.356
# 21         AD  Firefox    Linux           353   8.647
# 22         AQ       IE  Windows           591   1.897
# 23         SJ     Edge    Linux           340   4.897
# 24         ZW   Chrome      Mac           522  11.714
# 25         AF     Edge   iPhone           313  11.482
# 26         AS       IE   iPhone           300   3.222
# 27         MA  Firefox   iPhone           234   2.544
# 28         ER     Edge    Linux           466   4.371
# 29         SJ  Firefox      Mac           495   8.204
# 30         ZW   Chrome   iPhone           184   1.066
# 31         ZW       IE      Mac           135  11.568
# 32         SJ       IE   iPhone           258  12.025
# 33         AF     Edge  Windows           233   4.947
# 34         ZW     Edge  Windows           551   3.096
# 35         SJ   Chrome   iPhone           457   9.705
# 36         AS       IE      Mac           247  12.665
# 37         AL   Chrome  Windows           289   6.217
# 38         AF   Chrome      Mac           404  11.463
# 39         AL       IE    Linux           422   5.917
# 40         ZW       IE  Windows           271   4.211
# 41         AF  Firefox  Windows           329   4.689
# 42         AQ     Edge  Windows           591   0.175
# 43         AQ   Chrome  Windows           416   8.540
# 44         AL  Firefox    Linux           137   5.504
# 45         AQ     Edge   iPhone           228   1.706
# 46         SJ  Firefox      Mac           345   2.821
# 47         GD  Firefox      Mac           152   5.491
# 48         MA       IE      Mac           170  11.030
# 49         MA   Chrome      Mac           203   7.396
# 50         AF   Chrome    Linux           430   2.254
# 51         MA     Edge      Mac           477   6.703
# 52         GD     Edge  Windows           346   2.267
# 53         GD     Edge  Windows           580   9.285
# 54         GD  Firefox      Mac           110   9.229
# 55         SJ  Firefox      Mac           240   7.510
# 56         ZW       IE  Windows           427  10.504
# 57         SJ     Edge  Windows           457   3.103
# 58         ZW     Edge   iPhone           124   3.239
# 59         ER     Edge      Mac           337  12.420

# %%
#['ER','SJ','MA','GD','ZW']['AF','AL','AS','AD','AQ']

country_location = {}
country_location['ER'] = "15.1794,39.7823"
country_location['SJ'] = "77.5536,23.6703"
country_location['MA'] = "31.7917,7.0926"
country_location['GD'] = "12.1165,61.6790"
country_location['ZW'] = "19.0154,29.1549"
country_location['AF'] = "33.9391,67.7100"
country_location['AL'] = "41.1533,20.1683"
country_location['AS'] = "37.0902,95.7129"
country_location['AD'] = "42.5063,1.5218"
country_location['AQ'] = "-75.250973,-0.071389"
country_location
# Out:
# {'ER': '15.1794,39.7823',
#  'SJ': '77.5536,23.6703',
#  'MA': '31.7917,7.0926',
#  'GD': '12.1165,61.6790',
#  'ZW': '19.0154,29.1549',
#  'AF': '33.9391,67.7100',
#  'AL': '41.1533,20.1683',
#  'AS': '37.0902,95.7129',
#  'AD': '42.5063,1.5218',
#  'AQ': '-75.250973,-0.071389'}

# %%
df['location']=df['us_country'].map(country_location)

# %%
df[['eventTime']]
# Out:
#                    eventTime
# 0  2019-11-22 12:00:00+00:00
# 1  2019-11-22 12:10:01+00:00
# 2  2019-11-22 12:21:40+00:00
# 3  2019-11-22 12:31:51+00:00
# 4  2019-11-22 12:43:25+00:00
# 5  2019-11-22 12:54:15+00:00
# 6  2019-11-22 13:05:45+00:00
# 7  2019-11-22 13:17:01+00:00
# 8  2019-11-22 13:28:06+00:00
# 9  2019-11-22 13:38:32+00:00
# 10 2019-11-22 13:49:14+00:00
# 11 2019-11-22 13:59:45+00:00
# 12 2019-11-22 14:10:31+00:00
# 13 2019-11-22 14:21:36+00:00
# 14 2019-11-22 14:32:10+00:00
# 15 2019-11-22 14:42:47+00:00
# 16 2019-11-22 14:53:04+00:00
# 17 2019-11-22 15:03:35+00:00
# 18 2019-11-22 15:14:31+00:00
# 19 2019-11-22 15:25:33+00:00
# 20 2019-11-22 15:35:38+00:00
# 21 2019-11-22 16:00:00+00:00
# 22 2019-11-22 16:10:00+00:00
# 23 2019-11-22 16:20:45+00:00
# 24 2019-11-22 16:32:22+00:00
# 25 2019-11-22 16:45:34+00:00
# 26 2019-11-22 16:58:35+00:00
# 27 2019-11-22 17:10:55+00:00
# 28 2019-11-22 17:23:48+00:00
# 29 2019-11-22 17:35:39+00:00
# 30 2019-11-22 17:48:11+00:00
# 31 2019-11-22 17:58:30+00:00
# 32 2019-11-22 18:10:01+00:00
# 33 2019-11-22 18:20:21+00:00
# 34 2019-11-22 18:31:11+00:00
# 35 2019-11-22 18:44:01+00:00
# 36 2019-11-22 18:57:20+00:00
# 37 2019-11-22 19:08:01+00:00
# 38 2019-11-22 19:18:27+00:00
# 39 2019-11-22 19:30:12+00:00
# 40 2019-11-22 19:42:15+00:00
# 41 2019-11-22 19:53:31+00:00
# 42 2019-11-22 20:03:37+00:00
# 43 2019-11-22 20:16:52+00:00
# 44 2019-11-22 20:28:25+00:00
# 45 2019-11-22 20:40:42+00:00
# 46 2019-11-22 20:53:18+00:00
# 47 2019-11-22 21:05:28+00:00
# 48 2019-11-22 21:16:19+00:00
# 49 2019-11-22 21:29:29+00:00
# 50 2019-11-22 21:42:28+00:00
# 51 2019-11-22 22:00:00+00:00
# 52 2019-11-22 22:08:34+00:00
# 53 2019-11-22 22:21:36+00:00
# 54 2019-11-22 22:30:57+00:00
# 55 2019-11-22 22:33:19+00:00
# 56 2019-11-22 22:46:01+00:00
# 57 2019-11-22 22:58:27+00:00
# 58 2019-11-22 23:10:13+00:00
# 59 2019-11-22 23:17:19+00:00

# %%
f = open("curl_p4.sh", "w")
for i in range(len(df)):
    f.write("""curl -XPOST 'localhost:9200/hw11_p4_index/_doc/""" +str(i)+ """?pretty' -H 'Content-Type: application/json' -d '""")
    f.write(df.iloc[i].to_json(orient='index'))
    f.write("""'\n""")
f.close()
