# %%
import pandas as pd
import numpy as np
import random

# %%
def generate_df(id_list, timestring, min_interval, max_interval, url_list, user_list, country_list):

    df = pd.DataFrame(id_list)
    df[0] = df[0].astype(str).apply(lambda x: 'id'+x)

    #generate incremental time
    #time_list = [pd.Timestamp('2019-11-22T00Z')]
    time_list = [pd.Timestamp(timestring)]
    for i in range(1,len(df)):
        time_list.append( time_list[-1] + pd.Timedelta(seconds=random.randint(min_interval,max_interval)) )
    df[1] = time_list

    #generate url
    df[2] = np.random.choice(url_list, size=len(df))

    #generate user
    df[3] = np.random.choice(user_list, size=len(df))

    #generate country
    df[4] = np.random.choice(country_list, size=len(df))

    #generate browser
    df[5]  = np.random.choice(['Chrome','Firefox','Edge','IE'], size=len(df))

    #generate OS
    df[6] = np.random.choice(['Mac','Linux','iPhone','Windows'], size=len(df))

    #generate Response
    df[7] = np.random.randint(100,600,size=len(df))

    #generate TTFB
    df[8] = np.random.uniform(0.1,13,size=len(df))
    df[8] = df[8].round(3)
    
    return df

# %%
url_list = ['http://100.com/100','http://200.com/200','http://300.com/300',\
                'http://400.com/400','http://500.com/500']

user_list = ['user9000','user800','user10','user77','user55']

country_list = ['ER','SJ','MA','GD','ZW']

big_url_list = url_list + ['http://google.com/cow','http://bing.com/cat','http://espn.com/ball',\
                'http://espn.com/ball','http://amazon.com/fire']

big_user_list = user_list + ['bob','carly','moo','bigbig','buck']

big_country_list = country_list + ['AF','AL','AS','AD','AQ']

timestring = '2019-11-22T12Z'
id_list = list(range(0,21))
min_interval = 100
max_interval = 200

df_1 = generate_df(id_list, timestring, min_interval, max_interval, url_list, user_list, country_list)

timestring = '2019-11-22T13Z'
id_list = list(range(21,51))
min_interval = 100
max_interval = 200

df_2 = generate_df(id_list, timestring, min_interval, max_interval, big_url_list, big_user_list, big_country_list)

timestring = '2019-11-22T14Z'
id_list = list(range(51,60))
min_interval = 100
max_interval = 200

df_3 = generate_df(id_list, timestring, min_interval, max_interval, url_list, user_list, country_list)


df = pd.concat([df_1,df_2,df_3])
df = df.reset_index(drop = True)
df = df.rename(columns={0: "logId", 1: "eventTime", 2: "url", 3:"userId", 4:"us_country", 5:"browser", 6:"ua_os", 7:"responseCode", 8:"ttfb"})
df
# Out:
#    logId                 eventTime                     url    userId  \
# 0    id0 2019-11-22 12:00:00+00:00      http://300.com/300  user9000
# 1    id1 2019-11-22 12:01:47+00:00      http://500.com/500    user55
# 2    id2 2019-11-22 12:03:39+00:00      http://500.com/500    user55
# 3    id3 2019-11-22 12:06:38+00:00      http://100.com/100    user55
# 4    id4 2019-11-22 12:08:50+00:00      http://500.com/500   user800
# 5    id5 2019-11-22 12:11:12+00:00      http://300.com/300    user55
# 6    id6 2019-11-22 12:13:58+00:00      http://500.com/500    user10
# 7    id7 2019-11-22 12:16:35+00:00      http://200.com/200    user10
# 8    id8 2019-11-22 12:18:29+00:00      http://400.com/400   user800
# 9    id9 2019-11-22 12:20:56+00:00      http://500.com/500    user55
# 10  id10 2019-11-22 12:23:13+00:00      http://100.com/100   user800
# 11  id11 2019-11-22 12:25:08+00:00      http://100.com/100   user800
# 12  id12 2019-11-22 12:27:59+00:00      http://200.com/200  user9000
# 13  id13 2019-11-22 12:30:57+00:00      http://400.com/400    user10
# 14  id14 2019-11-22 12:32:53+00:00      http://500.com/500   user800
# 15  id15 2019-11-22 12:35:52+00:00      http://100.com/100   user800
# 16  id16 2019-11-22 12:38:17+00:00      http://200.com/200    user10
# 9          GD       IE   iPhone           434  10.314
# 10         SJ       IE   iPhone           484   2.579
# 11         MA     Edge   iPhone           225   4.869
# 12         MA     Edge      Mac           341   5.279
# 13         ER       IE      Mac           235   8.326
# 14         MA     Edge  Windows           326   9.869
# 15         SJ     Edge   iPhone           167   4.954
# 16         MA   Chrome      Mac           116  12.136
# 17         MA       IE    Linux           466  12.639
# 18         GD  Firefox   iPhone           490  12.752
# 19         ZW     Edge  Windows           404   0.442
# 20         ZW     Edge  Windows           161   8.822
# 21         AQ     Edge  Windows           573   2.222
# 22         AD   Chrome    Linux           533   0.787
# 23         AF     Edge   iPhone           585  12.608
# 24         SJ   Chrome  Windows           181   7.630
# 25         ER     Edge  Windows           363  11.637
# 26         AD   Chrome  Windows           377  10.663
# 27         SJ       IE      Mac           404  11.652
# 28         GD       IE   iPhone           460   8.506
# 29         AL     Edge      Mac           228   6.612
# 30         AF   Chrome   iPhone           300  10.986
# 31         AD     Edge    Linux           461   8.566
# 32         SJ   Chrome   iPhone           528   5.372
# 33         ZW   Chrome    Linux           473   9.769
# 34         AQ   Chrome  Windows           153  12.223
# 35         AD     Edge   iPhone           407   0.358
# 36         AD     Edge   iPhone           174   0.527
# 37         ER       IE      Mac           190   9.146
# 38         AL     Edge  Windows           575   5.191
# 39         ZW       IE      Mac           280   2.050
# 40         ZW       IE  Windows           449   9.301
# 41         ER     Edge    Linux           287   4.532
# 42         AQ   Chrome    Linux           183   9.102
# 43         AD  Firefox    Linux           407   7.869
# 44         AQ   Chrome    Linux           431   3.230
# 45         SJ  Firefox  Windows           347   0.479
# 46         AQ  Firefox  Windows           496   0.492
# 47         AQ  Firefox  Windows           592   2.107
# 48         AL   Chrome  Windows           420   3.640
# 49         AF   Chrome    Linux           586   6.241
# 50         AD   Chrome   iPhone           374   7.184
# 51         GD       IE   iPhone           524   8.082
# 52         MA     Edge   iPhone           141  11.138
# 53         SJ       IE  Windows           328  10.567
# 54         SJ   Chrome   iPhone           273  10.919
# 55         ZW  Firefox      Mac           186  10.278
# 56         ZW   Chrome      Mac           422   6.513
# 57         SJ   Chrome  Windows           542   1.075
# 58         ER   Chrome      Mac           275   0.569
# 59         SJ     Edge  Windows           357   7.785

# %%
import requests

# %%
headers = {
    'Content-type': 'application/json',
}

data=\
"""
{
    "logId":"id0000",
    "eventTime":"2018-04-10T15:15:30Z",
    "url":"http://google.com/rum2",
    "us_country":"Russia",
    "userId":"u3",
    "browser":"CHROME2",
    "ua_os":"MacOSX10.1",
    "responseCode":200,
    "ttfb":6.9
}
"""


requests.post('http://localhost:9200/hw11_p2_index/_doc/0', headers=headers, data=data)
# Out:
# <Response [200]>

# %%
df.iloc[0].to_json(orient='index')
# Out:
# '{"0":"id0","1":1574424000000,"2":"http:\\/\\/300.com\\/300","3":"user77","4":"SJ","5":"Firefox","6":"iPhone","7":174,"8":6.311}'

# %%
headers = {
    'Content-type': 'application/json',
}

data=\
'{"0":"id0","1":1574424000000,"2":"http:\\/\\/300.com\\/300","3":"user77","4":"SJ","5":"Firefox","6":"iPhone","7":174,"8":6.311}'


requests.post('http://localhost:9200/hw11_p2_index/_doc/0', headers=headers, data=data)
# Out:
# <Response [200]>

# %%
f = open("curl_p2.sh", "w")
for i in range(len(df)):
    f.write("""curl -XPOST 'localhost:9200/hw11_p2_index/_doc/""" +str(i)+ """?pretty' -H 'Content-Type: application/json' -d '""")
    f.write(df.iloc[i].to_json(orient='index'))
    f.write("""'\n""")
f.close()
